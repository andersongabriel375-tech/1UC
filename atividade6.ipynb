# %%
for i in range(1,4):

# %%
sair =  'SIM'
candidatos = {
    'nomes': [],
    'idades':[],
    'cidades': [],
    'vagas':[]
}

while sair == 'SIM':
    nome = input('Nome: ')
    idade = int(input('idade: '))
    cidade = input('cidade')
    vaga = input('Vaga: ')
